# %%
import repo_chat.git2vectors as git2vectors
from repo_chat.eval_utils import MultiQueryEvaluator
# Out:
# c:\Users\voyno\Desktop\code\repos\repo-chat\venv\lib\site-packages\pinecone\index.py:4: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
# run multiple queries n times each

queries = [
    "Explain this to me like I'm 5.",
    "What does this do?",
    "What is the point of the .env file?",
    "Can my junior dev create a website?",
]

evaluator = MultiQueryEvaluator(
    git2vectors.get_vectorstore, queries, runs_per_query=4
)
evaluator.evaluate()
# Out:
# MultiQueryEvaluator initialized with the following configurations:
# Number of queries: 4
# Runs per query: 4
# Total evaluations: 16
# Parallelized by query using concurrent.futures.ProcessPoolExecutor

# %%
# extract data from evalutation run

chainlogs_df, response_df = evaluator.flatten_responses()

# %%
chainlogs_df
# Out:
#         timestamp         chain_name
# 0    1.685050e+09  CONTEXT_VALIDATOR  \
# 1    1.685050e+09      UPGRADE_QUERY
# 2    1.685050e+09  CONTEXT_VALIDATOR
# 3    1.685050e+09  CONTEXT_VALIDATOR
# 4    1.685050e+09  CONTEXT_VALIDATOR
# ..            ...                ...
# 173  1.685050e+09      UPGRADE_QUERY
# 174  1.685050e+09  CONTEXT_VALIDATOR
# 175  1.685050e+09  CONTEXT_VALIDATOR
# 176  1.685050e+09  CONTEXT_VALIDATOR
# 177  1.685050e+09      RUN_QUERY_RAG
#
#                                             input_data
# 0    {"query": "Explain this to me like I'm 5.", "s...  \
# 1                     "Explain this to me like I'm 5."
# 2    {"query": "Can you explain what a code reposit...
# 3    {"query": "How can I use a code repository to ...
# 4    {"query": "What are the benefits of using a co...
# ..                                                 ...
# 173              "Can my junior dev create a website?"
# 174  {"query": "What are the requirements for a jun...
# 175  {"query": "Can the code repository provide res...
# 176  {"query": "Are there any restrictions or limit...
# 177  {"query": "Are there any restrictions or limit...
#
#                                            output_data  execution_time
# 0                                                 "50"        0.591342  \
# 1    "1. Can you explain what a code repository is ...        7.799198
# 2                                                 "20"        0.798342
# 3                                                 "50"        0.673496
# 4                                                 "50"        0.731530
# ..                                                 ...             ...
# 173  "1. What are the requirements for a junior dev...       10.199116
# 174                                               "20"        0.661208
# 175                                               "30"        0.601033
# 176                                               "50"        0.767406
# 177  "# Restrictions or Limitations for Junior Deve...       44.616607
#
#                                    query
# 0         Explain this to me like I'm 5.
# 1         Explain this to me like I'm 5.
# 2         Explain this to me like I'm 5.
# 3         Explain this to me like I'm 5.
# 4         Explain this to me like I'm 5.
# ..                                   ...
# 173  Can my junior dev create a website?
# 174  Can my junior dev create a website?
# 175  Can my junior dev create a website?
# 176  Can my junior dev create a website?
# 177  Can my junior dev create a website?
#
# [178 rows x 6 columns]

# %%
response_df
# Out:
#                                   query
# 0        Explain this to me like I'm 5.  \
# 1        Explain this to me like I'm 5.
# 2        Explain this to me like I'm 5.
# 3        Explain this to me like I'm 5.
# 4                    What does this do?
# 5                    What does this do?
# 6                    What does this do?
# 7                    What does this do?
# 8   What is the point of the .env file?
# 9   What is the point of the .env file?
# 10  What is the point of the .env file?
# 11  What is the point of the .env file?
# 12  Can my junior dev create a website?
# 13  Can my junior dev create a website?
# 14  Can my junior dev create a website?
# 15  Can my junior dev create a website?
#
#                                     similar_documents
# 0   - simply add to the prompt as they discover un...  \
# 1   - **Markdown is all you need** - Markdown is t...
# 2   - simply add to the prompt as they discover un...
# 3   - simply add to the prompt as they discover un...
# 4   - simply add to the prompt as they discover un...
# 5   The program is a Chrome extension that summari...
# 6   - simply add to the prompt as they discover un...
# 7   - simply add to the prompt as they discover un...
# 8   .env\r\n__pycache__\r\n.vscode\r\n# Ignore eve...
# 9   .env\r\n__pycache__\r\n.vscode\r\n# Ignore eve...
# 10  .env\r\n__pycache__\r\n.vscode\r\n# Ignore eve...
# 11  .env\r\n__pycache__\r\n.vscode\r\n# Ignore eve...
# 12  # smol developer\r\n\r\n***Human-centric & Coh...
# 13  # smol developer\r\n\r\n***Human-centric & Coh...
# 14  # smol developer\r\n\r\n***Human-centric & Coh...
# 15  # smol developer\r\n\r\n***Human-centric & Coh...
#
#                                                  text score
# 0   # Understanding Code Repositories\n\nA code re...    90
# 1   # Benefits of Using a Code Repository for Coll...    90
# 2   # Understanding Code Repositories\n\nA code re...    90
# 3   # Storing and Managing Code with a Code Reposi...    80
# 4   # Purpose of Smol Developer Code Repository\n\...    80
# 5   # Overview of Code Functionality\n\nThis code ...    90
# 6   # Purpose of Smol Developer Code Repository\n\...    85
# 7   # Purpose of Smol Developer Code Repository\n\...    90
# 8   ## Purpose of .env file in a code repository\n...    95
# 9   ## Purpose of .env file in a code repository\n...    95
# 10  ## Purpose of .env file in a code repository\n...    95
# 11  ## Purpose of .env file in a code repository\n...    95
# 12  # Restrictions or Limitations for Junior Devel...    90
# 13  ## Restrictions or Limitations for Junior Deve...    90
# 14  # Restrictions and Limitations for Junior Deve...    90
# 15  # Restrictions or Limitations for Junior Devel...    90
